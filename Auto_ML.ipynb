# %% [raw]
# Le minimum de votre class AutoML  :
# -prétraitement
#    reduction de la taille de votre dataset (float64 => float32, object => category etc.)
#    - sur les variables catégoriques :
#         - gestion des nan
#         - label encoder
#     - sur les variables numériques:
#          - gestion des nan
#         - normalisation
# prediction :
#     - détecter automatiquement si c'est un problème de classification ou de régression
#     - en fonction, utiliser les algos appropriés
#     -  ressortir les performances du modèle
# get_ypred('test.csv') :
#      return ypred
#
# save_ypred('test.csv') => sauvegarde le fichier de prediction prêt à être soumis sur kaggle

# %%
#Boite à import 
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
train = pd.read_csv("train.csv")
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
for col in train.columns:
    if col in train.select_dtypes(include = [np.object]):
        train[col] = train[col].astype('category')
    elif col in train.select_dtypes(include = [np.int64]):
        train[col] = train[col].astype(np.int32)
    elif col in train.select_dtypes(include = [np.float64]):
        train[col] = train[col].astype(np.float32)

# %%
for col in train:
    if train[col].nunique() >= 100 :
        print('ok')
    else:
        print('no',train[col].nunique())
# Out:
# ok
# no 15
# no 5
# ok
# ok
# no 2
# no 2
# no 4
# no 4
# no 2
# no 5
# no 3
# no 25
# no 9
# no 8
# no 5
# no 8
# no 10
# no 9
# ok
# no 61
# no 6
# no 8
# no 15
# no 16
# no 4
# ok
# no 4
# no 5
# no 6
# no 4
# no 4
# no 4
# no 6
# ok
# no 6
# ok
# ok
# ok
# no 6
# no 5
# no 2
# no 5
# ok
# ok
# no 24
# ok
# no 4
# no 3
# no 4
# no 3
# no 8
# no 4
# no 4
# no 12
# no 7
# no 4
# no 5
# no 6
# no 97
# no 3
# no 5
# ok
# no 5
# no 5
# no 3
# ok
# ok
# ok
# no 20
# no 76
# no 8
# no 3
# no 4
# no 4
# no 21
# no 12
# no 5
# no 9
# no 6
# ok

# %%
,train[col].nunique()print(train['Street'].nunique())
# Out:
# 2

# %%
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
test = pd.read_csv("test.csv")
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
train.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int32
# MSSubClass       1460 non-null int32
# MSZoning         1460 non-null category
# LotFrontage      1201 non-null float32
# LotArea          1460 non-null int32
# Street           1460 non-null category
# Alley            91 non-null category
# LotShape         1460 non-null category
# LandContour      1460 non-null category
# Utilities        1460 non-null category
# LotConfig        1460 non-null category
# LandSlope        1460 non-null category
# Neighborhood     1460 non-null category
# Condition1       1460 non-null category
# Condition2       1460 non-null category
# BldgType         1460 non-null category
# HouseStyle       1460 non-null category
# OverallQual      1460 non-null int32
# OverallCond      1460 non-null int32
# YearBuilt        1460 non-null int32
# YearRemodAdd     1460 non-null int32
# ...

# %%
"""for dtype in ['float','int','object']:
    selected_dtype = train.select_dtypes(include=[dtype])
    mean_usage_b = selected_dtype.memory_usage(deep=True).mean()
    mean_usage_mb = mean_usage_b / 1024 ** 2
    print("Average memory usage for {} columns: {:03.2f} MB".format(dtype,mean_usage_mb))"""
# Out:
# Average memory usage for float columns: 0.01 MB
# Average memory usage for int columns: 0.01 MB
# Average memory usage for object columns: 0.08 MB

# %%
class Auto_ML(dataset, y):
    def __init__(self, data_filename, target):    
        self.data = pd.read_csv(data_filename)   # load data
        self.y = self.data[target]               # détermination var dépendante
        self.X = self.data.drop(target)          # détermination var indépendante(s)
        self.scaler = StandardScaler()


    def convert_column(self):
        for col in train.columns:
            if col in train.select_dtypes(include = [np.object]):
                self.X[col] = self.X[col].astype('category')
            elif col in train.select_dtypes(include = [np.int64]):
                self.X[col] = self.X[col].astype(np.int32)
            elif col in train.select_dtypes(include = [np.float64]):
                self.X[col] = self.X[col].astype(np.float32)


    def model(self):
        self.model['Linear Regression'] = LinearRegression()
        self.model['Logistic Regression'] = LogisticRegression(random_state=0)
        self.model['SVM'] = SVC(random_state=0, kernel='rbf')
        self.model['Random Forest'] = RandomForestClassifier(random_state=0)
        
    def predict(self): 
        # suppression des col contenant que des valeurs uniques et dont le % de Nan > 20%
        for col in self.X.columns:
            if len(np.unique(self.X[col])) == len(self.X): 
                self.X = self.X.drop(col, axis = 1)

            elif (self.X[col].isna.sum()* 100)/len(self.X) > 24:
                self.X = self.X.drop(col, axis = 1)

        # Remplacer des NaN 
        for col in self.X.columns:
            if col in self.X.select_dtypes(include = [np.number]):
                mean = np.mean(self.X[col])
                self.X[col].fillna(mean, inplace = True)

            else:
                self.X[col].fillna(self.X[col].mode, inplace = True)


        # Normalisation
        for col in self.X.columns:
            if col in self.X.select_dtypes(include = [np.number]):
                self.scaler.fit(self.X[col])
                self.scaler.transform(self.X[col])


        # Transformation des var catégorielles en var numériques (get dummies) => self.X
        for col in self.X.columns:
            if len(np.unique(self.X[col])) > 150 : 
                if col in self.X.select_dtypes(include = [np.object]):
                    self.X = pd.get_dummies(self.X[col], drop_first=True)

        # LabelEncoder => y exclusivement car je ne souhaite pas avoir plusieurs cols
            if len(np.unique(self.X[col])) => 150 : 
                if col in self.X.select_dtypes(include = [np.object]):
                    self.X[col] = self.X[col].cat.codes
        #Si les éléments de la colonne sont superieur à 5 alors on fait Label Encoder
